# %% [markdown]
# # Decision Tree
#
# Decision trees are a fundamental and intuitive machine learning algorithm used for both classification and regression tasks. They work by partitioning the data into subsets based on feature values, creating a tree-like structure of decisions.
# Tree Structure:
#
#     A decision tree is structured like a flowchart, with:
#         Nodes: Representing decisions based on feature values.
#         Branches: Representing the outcomes of those decisions.
#         Leaves: Representing the final predictions.
#
# Recursive Partitioning:
#
#     The algorithm recursively splits the data into smaller subsets based on the features that best separate the data points.
#     At each node, the algorithm selects the feature and the threshold that result in the most homogeneous subsets (i.e., subsets with data points belonging to the same class or having similar target values).
#
#     Feature Selection:
#
#     The algorithm uses metrics like:
#         Gini impurity (for classification): Measures the degree of impurity in a set of data points.
#         Information gain (for classification): Measures the reduction in entropy (uncertainty) after splitting the data.
#         Mean squared error (for regression): Measures the average squared difference between predicted and actual values.
#     To determine the best feature and threshold for each split.
#
#  How it Works:
#
#     Start at the Root: The algorithm starts with the entire dataset at the root node.
#     Select the Best Feature: It selects the feature that best splits the data based on the chosen metric (e.g., Gini impurity or information gain).
#     Create Branches: It creates branches for each possible value or range of values of the selected feature.
#     Recursive Splitting: It recursively repeats steps 2 and 3 for each branch, creating subtrees until a stopping criterion is met.
#     Stopping Criteria:
#         Maximum tree depth.
#         Minimum number of samples per leaf node.
#         Minimum impurity reduction.
#     Prediction:
#         For classification, the leaf node with the majority class label is assigned as the prediction.
#         For regression, the average or mean value of the leaf node is the prediction.
#
# Key Advantages:
#
#     Interpretability: Decision trees are easy to understand and visualize, making them highly interpretable.
#     Handles Both Categorical and Numerical Data: They can handle both types of features without requiring extensive preprocessing.
#     Nonlinear Relationships: They can capture nonlinear relationships between features and the target variable.
#     Feature Importance: They provide a measure of feature importance, indicating which features are most relevant for prediction.
#
# Key Disadvantages:
#
#     Overfitting: Decision trees are prone to overfitting, especially when they are allowed to grow too deep.
#     Sensitivity to Small Changes: Small changes in the data can lead to significant changes in the tree structure.
#     Instability: They can be unstable, meaning that small variations in the training data can lead to different trees.
#     Bias: If some classes dominate, they can create biased trees.
#
# Applications:
#
#     Classification problems (e.g., spam detection, medical diagnosis).
#     Regression problems (e.g., predicting house prices, stock market analysis).
#     Feature selection.
#
# To mitigate overfitting, techniques like pruning and ensemble methods (e.g., Random Forest, Gradient Boosting) are often used in conjunction with decision trees.

# %%
#import required libraries

import numpy as np
import pandas as pd
import seaborn as sns

# %%
#import dataset


df = pd.read_csv("Breast_cancer_dataset.csv")

# %%
#show first 5 records
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
#drop not required feature

df.drop(['Unnamed: 32'] , axis=1,inplace=True)

# %%
#verify features and check for null values and datatype

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
#import decision tree classifier

from sklearn.model_selection import train_test_split

from sklearn.tree import DecisionTreeClassifier

#create independent variables X and dependent variable Y dataset

x=df.drop('diagnosis', axis=1)
y= df['diagnosis']

# %%
#split data between training and test set
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=42)

# %%
#apply decision tree
from sklearn.tree import DecisionTreeClassifier

clf_model =DecisionTreeClassifier(criterion= "gini", random_state=42 ,max_depth=3, min_samples_leaf=5)

clf_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, min_samples_leaf=5, random_state=42)

# %%
#create prediction
y_pred = clf_model.predict(x_test)

# %%
#create confusion matrix to understand errors

from sklearn.metrics import confusion_matrix, classification_report

print(confusion_matrix(y_test, y_pred))
# Out:
# [[106   2]
#  [  3  60]]

# %%
#generate classification report to understand accuracy 

print(classification_report(y_test ,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.97      0.98      0.98       108
#            M       0.97      0.95      0.96        63
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %%
#show output



target =list(df['diagnosis'].unique())

feature_names = list(x.columns)

from sklearn.tree import export_text

from sklearn.tree import export_graphviz

r= export_text(clf_model, feature_names = feature_names)

print(r)

#r= export_graphviz(clf_model, feature_names= feature_names)

#print(r)
# Out:
# |--- concave points_mean <= 0.05
# |   |--- radius_worst <= 16.83
# |   |   |--- area_se <= 43.10
# |   |   |   |--- class: B
# |   |   |--- area_se >  43.10
# |   |   |   |--- class: B
# |   |--- radius_worst >  16.83
# |   |   |--- texture_worst <= 19.91
# |   |   |   |--- class: B
# |   |   |--- texture_worst >  19.91
# |   |   |   |--- class: M
# |--- concave points_mean >  0.05
# |   |--- texture_worst <= 20.40
# |   |   |--- area_worst <= 892.15
# |   |   |   |--- class: B
# |   |   |--- area_worst >  892.15
# |   |   |   |--- class: M
# |   |--- texture_worst >  20.40
# |   |   |--- area_worst <= 718.65
# |   |   |   |--- class: B
# |   |   |--- area_worst >  718.65
# |   |   |   |--- class: M
